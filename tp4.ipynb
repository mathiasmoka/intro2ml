# %% [markdown]
# # Decision Tree et Random Forests
#
# ### Objectif: prédire le prix de biens imobiliers à partir de caratértistiques sur l'nevironnement

# %% [markdown]
# ### Installation des librairies nécessaires

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 56.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 48.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 55.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
# il vaut mieux faire avec la librairie indiquée car les librairies du sujet initial dépend de graphziv, galère à installer
import numpy as np
from sklearn.datasets import fetch_california_housing #car l'ancien dataset n'existe plus

data = fetch_california_housing()
X = data.data
y = data.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=17)

# Construction d'un arbre de décision
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(random_state=0).fit(X_train, y_train)

#Q1
def tree_summary(tree, X_train, y_train, X_test, y_test):
    # on utilise l'erreur quadratique moyenne pour le calcul du score
    print("Train score:", tree.score(X_train, y_train))
    print("Test score:", tree.score(X_test, y_test))
    print("Depth:", dt.tree_.max_depth)
    print("Nodes:", dt.tree_.node_count )
    return 

tree_summary(dt, X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 25
#      22     print("Nodes:", dt.tree_.node_count )
#      23     return
# ---> 25 tree_summary(dt, X_train, X_test, y_train, y_test)
#
# Cell In[15], line 19, in tree_summary(tree, X_train, y_train, X_test, y_test)
#      17 def tree_summary(tree, X_train, y_train, X_test, y_test):
#      18     # on utilise l'erreur quadratique moyenne pour le calcul du score
# ---> 19     print("Train score:", tree.score(X_train, y_train))
#      20     print("Test score:", tree.score(X_test, y_test))
#      21     print("Depth:", dt.tree_.max_depth)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/base.py:654, in RegressorMixin.score(self, X, y, sample_weight)
#     651 from sklearn.metrics import r2_score
#     653 y_pred = self.predict(X)
# ...

# %% [markdown]
# ## Q2:

# %%
#Q2
dt2 = DecisionTreeRegressor(random_state=0, max_depth=3).fit(X_train, y_train)

from sklearn import tree
import matplotlib.pyploy as plt

plt.figure(figsize=(12,6))
tree.plot_tree(dt2, filled=True)
plt.show()
#tree_summary(dt2, X.....)

#cette fois on a réglé le pb d'overfitting de l'arbre, mais l'arbre est devenu trop simple

# %% [markdown]
# ## Q4: Recherche de la profondeur optimale

# %%
# Q4 : on lance une boucle pour automatiser le test des profondeurs.
# Utilisation d'une validation croisée
# Obtention d'un graphique en forme de U
# le point optimal est le plus bas, car on a affiché 1-score
# au début : modèle trop simple, under-fitting
# à la fin : modèle trop complexe, donc over-fitting$
# le point optimal est vers le milieu

import matplotlib.pyplot as plot_tree
depths = range(1, 21)
cv_scores = []
for d in depths:
    tree = DecisionTreeRegressor(max_depth=d, random_state=0)
    score = np.mean(cross_val_score(tree, X_train, y_train, cv=10))
    cv_scores.append(score)

best_depth = depths[np.argmax(cv_scores)]
print("Best max_depth (10-fold CV):", best_depth)

plt.plot(depths, 1-np.array(cv_scores))
plt.xlabel("Depth of the tree")
plt.ylabel("CV error")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 14
#      12 for d in depths:
#      13     tree = DecisionTreeRegressor(max_depth=d, random_state=0)
# ---> 14     score = np.mean(cross_val_score(tree, X_train, y_train, cv=10))
#      15     cv_scores.append(score)
#      17 best_depth = depths[np.argmax(cv_scores)]
#
# NameError: name 'cross_val_score' is not defined

# %% [markdown]
# ## Q5: Score r2

# %% [markdown]
# ## Q6 : Introduction du concept de boostraping (=échantillonnage avec remise)

# %%
# on entraine des arbres sur chaque échantillon, pour créer de la diversité dans notre jeu de données
# ici, entrainement de 100 abrbres sur 100 échantillons différents
# concept fondateur des random forests

X_train, y_train = resample(X_train, y_train, n_samples=len(X_train), replace=True, random_state=0)
dt_boot = DecisionTreeRegressor(random_state=0).fit(X_train_, _train_)
print("Built-in R2:", dt_boot.score(X_test, y_test))

y_pred = dt_boot.predict(X_test)
print("Custom R2:", r2_score(y_test, y_pred))
#replace=True (autorise le tirage avec remise)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       1 # on entraine des arbres sur chaque échantillon, pour créer de la diversité dans notre jeu de données
#       2 # ici, entrainement de 100 abrbres sur 100 échantillons différents
#       3 # concept fondateur des random forests
# ----> 6 X_train, y_train = resample(X_train, y_train, n_samples=len(X_train), replace=True, random_state=0)
#       7 dt_boot = DecisionTreeRegressor(random_state=0).fit(X_train_, _train_)
#       8 print("Built-in R2:", dt_boot.score(X_test, y_test))
#
# NameError: name 'resample' is not defined

# %% [markdown]
# ## Remarques sur les fonctions utilisées ici :
#
#  .fit, .score et . ?? sont des fonctions qu'on utilsera tout le temps pour lancer l'entrainement, obtenir le score, etc.
#
# En revanche, en général on uitilisera directement des librairies pour XGBOOST, RandomForests etc, sauf refaire manuellement tout ce qu'on fait ici.
#
# Sauf en cas de sujets de recherche, ou pour simuler des données par exemple

# %%
#Q7

predictors = []
predicitions=[]

for seed in range(5):
    X_train, y_train = resample(X_train, y_train, replace=True, random_state=seed)
    tree = DecisionTreeRegressor(random_state=0).fit(X_train, y_train)

    #suite du code ?????

# %%
#Q8 : objectif = créer un prédicteur d'ensemble

avg_pred_2 = np.mean(predictions, axis=0)
# suite ???

# on regarde si ce modèle ets plus puissant.
# PAssage de ??? à 0,77 : c'est une amélioration significative en DS
# Le tout sans changer le modèle de base, juste en utilisant le moyennage des ...

# %% [markdown]
# ## Q9: Automatisation de l'entrainement d'une forêt d'arbre

# %%
# Q9: Automatisation de l'entrainement d'une forêt d'arbre
# regroupe les questions précédentes
# encapsulement des étapes

def tree_aggregation(n_trees, X_train, y_train, X_test, y_test):
    ### suite

# Conclusion :
# ajouter des arbres permet d'améliorer les performances
# mais le gain de performance va plafonner à un moment (ici à partir de 50 arbres envirion)

# %% [markdown]
# ## Q10: Notre fonction est-elle meilleur que l'algo de référence Randomforest ?

# %%
# en mettant les 2 approches avec exactement 5 arbres,
# notre fonction manuelle est meilleure (score 0.75 vs. 0.76)

# explication; RF regarde un seul ensemble aléatoire comme chaque coupure.
# donc pour seulement 5 abres, notre fonction avec plus de diversité va être meilleure

# pour 50 abres, l'écart est moins grand, mais notre fonction est toujours meilleure

rf = RandomForestRegressor(n_estimators=5, random_state=0).fit(X_train, y_train)
rf_score = rf.score(X_test, y_test)
print("RandomForestRegressor R2 score (5 trees):", rf_score)


rf = RandomForestRegressor(n_estimators+50, random_state=0).fit(X_train, y_train)
